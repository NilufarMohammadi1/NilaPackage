# %% [markdown]
# # I'm gonna test the package manually here
#
# In this notebook, I'm able to test the created package manually.For example U can give it ur desired dataframes with any kind of information and see how it turns out.Other methods of testing would be pytest.You can use pytest in terminal or ipykernel to test the dataframes and methods you coded.

# %% [markdown]
# Down below Sys library has been imported.This library helps you find out your current running directory.

# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\Ontime\\AppData\\Local\\Programs\\Python\\Python39\\python.exe'

# %% [markdown]
# As you might already know, jupyter notebook is not synced with the changes you make in your IDE.That is why we use magic code down below.This magic code which is obviously not python helps your environment to auto reload.It saves you a lot of troubles.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as nummy
import NilaPackage as np
import pandas as pd

# %%
name = nummy.array(['Nilufar', 'Negin', 'Nana'])
city = nummy.array(['Bushehr', 'Shiraz', 'Tehran'])
height = nummy.array([174, 165,166])
school = nummy.array([True, False, True])
weight = nummy.array([61, 69, 45])

data = {'name': name, 'city': city, 'height': height, 
        'school': school, 'weight': weight}

df = np.DataFrame(data)

# %%
df
# Out:
# <table style="border-collapse: collapse;margin: 25px 0;font-size: 0.9em;font-family: sans-serif;min-width: 400px;box-shadow: 0 0 20px rgba(0, 0, 0, 0.15);"><thead style="background-color: #009879;color: #ffffff;text-align: left;"><tr style=" border-bottom: 1px solid #dddddd;"><th></th><th >name      </th><th >city      </th><th >height    </th><th >school    </th><th >weight    </th></tr></thead><tbody><tr><td><strong>0</strong></td><td>Nilufar   </td><td>Bushehr   </td><td>       174</td><td>True</td><td>        61</td></tr><tr><td><strong>1</strong></td><td>Negin     </td><td>Shiraz    </td><td>       165</td><td>False</td><td>        69</td></tr><tr><td><strong>2</strong></td><td>Nana      </td><td>Tehran    </td><td>       166</td><td>True</td><td>        45</td></tr></tbody></table>

# %%
arr1 = nummy.array([1,2,3])
arr2 = nummy.array([4,5,6])
data = {'a':arr1,'b':arr2}
np.DataFrame(data)
# Out:
# <table style="border-collapse: collapse;margin: 25px 0;font-size: 0.9em;font-family: sans-serif;min-width: 400px;box-shadow: 0 0 20px rgba(0, 0, 0, 0.15);"><thead style="background-color: #009879;color: #ffffff;text-align: left;"><tr style=" border-bottom: 1px solid #dddddd;"><th></th><th >a         </th><th >b         </th></tr></thead><tbody><tr><td><strong>0</strong></td><td>         1</td><td>         4</td></tr><tr><td><strong>1</strong></td><td>         2</td><td>         5</td></tr><tr><td><strong>2</strong></td><td>         3</td><td>         6</td></tr></tbody></table>

# %%
len(df)
# Out:
# 3

# %%
df.columns
# Out:
# ['name', 'city', 'height', 'school', 'weight']

# %%
 ['fuck','u','bitch','u','f']
# Out:
# ['fuck', 'u', 'bitch', 'u', 'f']

# %%
df._data
# Out:
# {'name': array(['Nilufar', 'Negin', 'Nana'], dtype=object),
#  'city': array(['Bushehr', 'Shiraz', 'Tehran'], dtype=object),
#  'height': array([174, 165, 166]),
#  'school': array([ True, False,  True]),
#  'weight': array([61, 69, 45])}

# %%
df.shape
# Out:
# (3, 5)

# %%
df.values
# Out:
# array([['Nilufar', 'Bushehr', 174, True, 61],
#        ['Negin', 'Shiraz', 165, False, 69],
#        ['Nana', 'Tehran', 166, True, 45]], dtype=object)

# %%
df.dtypes
# Out:
# <table style="border-collapse: collapse;margin: 25px 0;font-size: 0.9em;font-family: sans-serif;min-width: 400px;box-shadow: 0 0 20px rgba(0, 0, 0, 0.15);"><thead style="background-color: #009879;color: #ffffff;text-align: left;"><tr style=" border-bottom: 1px solid #dddddd;"><th></th><th >Column Name</th><th >Data Type </th></tr></thead><tbody><tr><td><strong>0</strong></td><td>name      </td><td>string    </td></tr><tr><td><strong>1</strong></td><td>city      </td><td>string    </td></tr><tr><td><strong>2</strong></td><td>height    </td><td>int       </td></tr><tr><td><strong>3</strong></td><td>school    </td><td>bool      </td></tr><tr><td><strong>4</strong></td><td>weight    </td><td>int       </td></tr></tbody></table>

# %%
df
# Out:
# <table style="border-collapse: collapse;margin: 25px 0;font-size: 0.9em;font-family: sans-serif;min-width: 400px;box-shadow: 0 0 20px rgba(0, 0, 0, 0.15);"><thead style="background-color: #009879;color: #ffffff;text-align: left;"><tr style=" border-bottom: 1px solid #dddddd;"><th></th><th >name      </th><th >city      </th><th >height    </th><th >school    </th><th >weight    </th></tr></thead><tbody><tr><td><strong>0</strong></td><td>Nilufar   </td><td>Bushehr   </td><td>       174</td><td>True</td><td>        61</td></tr><tr><td><strong>1</strong></td><td>Negin     </td><td>Shiraz    </td><td>       165</td><td>False</td><td>        69</td></tr><tr><td><strong>2</strong></td><td>Nana      </td><td>Tehran    </td><td>       166</td><td>True</td><td>        45</td></tr></tbody></table>

# %%
df.read_csv_file_nila("C:\\Users\\Ontime\\Desktop\\employee.csv")
# Out:
# Column names are dept, race, gender, salary
# 	Houston Police Department-HPD works in the White department, and was born in Male.
# 	Houston Fire Department (HFD) works in the White department, and was born in Male.
# 	Houston Police Department-HPD works in the Black department, and was born in Male.
# 	Public Works & Engineering-PWE works in the Asian department, and was born in Male.
# 	Houston Airport System (HAS) works in the White department, and was born in Male.
# 	Public Works & Engineering-PWE works in the White department, and was born in Male.
# 	Houston Fire Department (HFD) works in the Hispanic department, and was born in Male.
# 	Health & Human Services works in the Black department, and was born in Male.
# 	Public Works & Engineering-PWE works in the Black department, and was born in Male.
# 	Health & Human Services works in the Black department, and was born in Male.
# 	Houston Police Department-HPD works in the Black department, and was born in Male.
# ...

# %%
df.read_txt_file_nila("C:\\Users\\Ontime\\Desktop\\gist.txt")
# Out:
# working directory -> staging area -> Git repository
#
# git status
#
# git log
#
# git add
#
# git add .
#
# git add filex.txt
#
# git commit -m filex.txt
#
# ls -la
#
# ls
#
# git ls-files -s
#
# ---------
# 4 git objects:
#
# git hash-object
#
# git mktree
#
# git commit
#
# annotated tag
# ---------
#
# git config --global user.name
# git config --global user.mail
#
# ---------
#
# git cat-file -p "sha1hash of file" -> content of file
# git cat-file -t "sha1hash of file" -> type of file being blob,tree,commit or annotated tag
# git cat-file -s "sha1hash of file" -> size of file
#
# ---------
#
# File life Cycle in Git : Untracked ------> to track a  file and move it to staging area we use the git add command.When it reaches the staged point of its life cycle ,u can use git commit command to move it to "unmodified" point of its lifecycle.if u want to unstage the file u just moved to stagin area, u can use git rm --cached filex.txt.
# ...

# %%
df.read_excel_file_nila("C:\\Users\\Ontime\\Desktop\\Sample_Student_data_xls.xls")
# Out:
# student_name	school_name	address
# Aleshia	Alan D Rosenburg Cpa Pc	14 Taylor St
# Evan	Cap Gemini America	5 Binney St
# France	Elliott, John W Esq	8 Moor Place
# Ulysses	Mcmahan, Ben L	505 Exeter Rd

# %%
df['city']
# Out:
# <table style="border-collapse: collapse;margin: 25px 0;font-size: 0.9em;font-family: sans-serif;min-width: 400px;box-shadow: 0 0 20px rgba(0, 0, 0, 0.15);"><thead style="background-color: #009879;color: #ffffff;text-align: left;"><tr style=" border-bottom: 1px solid #dddddd;"><th></th><th >city      </th></tr></thead><tbody><tr><td><strong>0</strong></td><td>Bushehr   </td></tr><tr><td><strong>1</strong></td><td>Shiraz    </td></tr><tr><td><strong>2</strong></td><td>Tehran    </td></tr></tbody></table>

# %%
df[['name','city']]
# Out:
# <table style="border-collapse: collapse;margin: 25px 0;font-size: 0.9em;font-family: sans-serif;min-width: 400px;box-shadow: 0 0 20px rgba(0, 0, 0, 0.15);"><thead style="background-color: #009879;color: #ffffff;text-align: left;"><tr style=" border-bottom: 1px solid #dddddd;"><th></th><th >name      </th><th >city      </th></tr></thead><tbody><tr><td><strong>0</strong></td><td>Nilufar   </td><td>Bushehr   </td></tr><tr><td><strong>1</strong></td><td>Negin     </td><td>Shiraz    </td></tr><tr><td><strong>2</strong></td><td>Nana      </td><td>Tehran    </td></tr></tbody></table>

# %%
df
# Out:
# <table style="border-collapse: collapse;margin: 25px 0;font-size: 0.9em;font-family: sans-serif;min-width: 400px;box-shadow: 0 0 20px rgba(0, 0, 0, 0.15);"><thead style="background-color: #009879;color: #ffffff;text-align: left;"><tr style=" border-bottom: 1px solid #dddddd;"><th></th><th >name      </th><th >city      </th><th >height    </th><th >school    </th><th >weight    </th></tr></thead><tbody><tr><td><strong>0</strong></td><td>Nilufar   </td><td>Bushehr   </td><td>       174</td><td>True</td><td>        61</td></tr><tr><td><strong>1</strong></td><td>Negin     </td><td>Shiraz    </td><td>       165</td><td>False</td><td>        69</td></tr><tr><td><strong>2</strong></td><td>Nana      </td><td>Tehran    </td><td>       166</td><td>True</td><td>        45</td></tr></tbody></table>

# %%
df['height'] + 5
# Out:
# <table style="border-collapse: collapse;margin: 25px 0;font-size: 0.9em;font-family: sans-serif;min-width: 400px;box-shadow: 0 0 20px rgba(0, 0, 0, 0.15);"><thead style="background-color: #009879;color: #ffffff;text-align: left;"><tr style=" border-bottom: 1px solid #dddddd;"><th></th><th >height    </th></tr></thead><tbody><tr><td><strong>0</strong></td><td>       179</td></tr><tr><td><strong>1</strong></td><td>       170</td></tr><tr><td><strong>2</strong></td><td>       171</td></tr></tbody></table>

# %%
df['height'] -500
# Out:
# <table style="border-collapse: collapse;margin: 25px 0;font-size: 0.9em;font-family: sans-serif;min-width: 400px;box-shadow: 0 0 20px rgba(0, 0, 0, 0.15);"><thead style="background-color: #009879;color: #ffffff;text-align: left;"><tr style=" border-bottom: 1px solid #dddddd;"><th></th><th >height    </th></tr></thead><tbody><tr><td><strong>0</strong></td><td>      -326</td></tr><tr><td><strong>1</strong></td><td>      -335</td></tr><tr><td><strong>2</strong></td><td>      -334</td></tr></tbody></table>

# %%
df['height'] *2
# Out:
# <table style="border-collapse: collapse;margin: 25px 0;font-size: 0.9em;font-family: sans-serif;min-width: 400px;box-shadow: 0 0 20px rgba(0, 0, 0, 0.15);"><thead style="background-color: #009879;color: #ffffff;text-align: left;"><tr style=" border-bottom: 1px solid #dddddd;"><th></th><th >height    </th></tr></thead><tbody><tr><td><strong>0</strong></td><td>       348</td></tr><tr><td><strong>1</strong></td><td>       330</td></tr><tr><td><strong>2</strong></td><td>       332</td></tr></tbody></table>
